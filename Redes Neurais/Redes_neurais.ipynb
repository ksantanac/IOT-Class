# %%
from sklearn.neural_network import MLPClassifier
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
iris = datasets.load_iris()

df = pd.DataFrame(iris.data, columns=['larg_sep', 'comp_sep', 'larg_pet', 'comp_pet'])
df.head(2)
# Out:
#    larg_sep  comp_sep  larg_pet  comp_pet
# 0       5.1       3.5       1.4       0.2
# 1       4.9       3.0       1.4       0.2

# %%
df['classe'] = iris.target
df
# Out:
#      larg_sep  comp_sep  larg_pet  comp_pet  classe
# 0         5.1       3.5       1.4       0.2       0
# 1         4.9       3.0       1.4       0.2       0
# 2         4.7       3.2       1.3       0.2       0
# 3         4.6       3.1       1.5       0.2       0
# 4         5.0       3.6       1.4       0.2       0
# ..        ...       ...       ...       ...     ...
# 145       6.7       3.0       5.2       2.3       2
# 146       6.3       2.5       5.0       1.9       2
# 147       6.5       3.0       5.2       2.0       2
# 148       6.2       3.4       5.4       2.3       2
# 149       5.9       3.0       5.1       1.8       2
#
# [150 rows x 5 columns]

# %%
len(df.columns)
# Out:
# 5

# %%
df.columns
# Out:
# Index(['larg_sep', 'comp_sep', 'larg_pet', 'comp_pet', 'classe'], dtype='object')

# %%
import pandas as pd
import numpy as np

def normalizar(x): #x será uma lista de valores numéricos
  return (x - np.min(x))/(np.max(x) - np.min(x))

def padronizar(x):
  return (x -np.mean(x))/np.std(x)


from scipy.stats import shapiro
# Verificar normalidade usando o teste de Shapiro-Wilk
def verifica_normalidade(dataframe, coluna):
    coluna_data = dataframe[coluna]
    # Realizar o teste de Shapiro-Wilk
    statistic, p_valor = shapiro(coluna_data)
    # Definir o nível de significância
    nivel_significancia = 0.1
    # Verificar se a hipótese nula de normalidade pode ser rejeitada
    if p_valor > nivel_significancia:
        print(f"A coluna '{coluna}' segue uma distribuição normal")
        return True
    else:
        print(f"A coluna '{coluna}' não segue uma distribuição normal")
        return False

# %%
# Chamando a função para verificar normalidade
for coluna in df.drop('classe', axis=1).columns:#['larg_sep', 'comp_sep', 'larg_pet', 'comp_pet']
  if verifica_normalidade(df, coluna):
    df[coluna] = padronizar(df[coluna])#se for distribuição normal, padroniza
  else:#senão, normaliza
    df[coluna] = normalizar(df[coluna])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Chamando a função para verificar normalidade
# ----> 2 for coluna in df.drop('classe', axis=1).columns:#['larg_sep', 'comp_sep', 'larg_pet', 'comp_pet']
#       3   if verifica_normalidade(df, coluna):
#       4     df[coluna] = padronizar(df[coluna])#se for distribuição normal, padroniza
#
# File c:\Users\Gamer\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File c:\Users\Gamer\anaconda3\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File c:\Users\Gamer\anaconda3\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File c:\Users\Gamer\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['classe'] not found in axis"

# %%
df
# Out:
#      larg_sep  comp_sep  larg_pet  comp_pet  classe
# 0    0.222222  1.019004  0.067797  0.041667       0
# 1    0.166667 -0.131979  0.067797  0.041667       0
# 2    0.111111  0.328414  0.050847  0.041667       0
# 3    0.083333  0.098217  0.084746  0.041667       0
# 4    0.194444  1.249201  0.067797  0.041667       0
# ..        ...       ...       ...       ...     ...
# 145  0.666667 -0.131979  0.711864  0.916667       2
# 146  0.555556 -1.282963  0.677966  0.750000       2
# 147  0.611111 -0.131979  0.711864  0.791667       2
# 148  0.527778  0.788808  0.745763  0.916667       2
# 149  0.444444 -0.131979  0.694915  0.708333       2
#
# [150 rows x 5 columns]

# %%
X = df.drop('classe', axis=1)
y = df['classe']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=30)

# %%
redeneural = MLPClassifier(verbose=False,
                           max_iter=15000,
                           learning_rate_init=0.00001,
                           hidden_layer_sizes=(4, 4),
                           tol=0.000001, activation='relu'
                           )
redeneural.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(4, 4), learning_rate_init=1e-05,
#               max_iter=15000, tol=1e-06)

# %%
from sklearn.metrics import accuracy_score
y_pred = redeneural.predict(X_test)

# Avaliar a acurácia do modelo
accuracy = accuracy_score(y_test, y_pred)
print("Acurácia da rede neural:", accuracy)
# Out:
# Acurácia da rede neural: 0.5555555555555556
